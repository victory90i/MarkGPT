# %%
parts = filename.split('_')

# Extract model architecture: after 'model' -> index 1
model_arch = parts[1]

# Extract epoch number: after 'epoch' -> index 3, convert to int
epoch_num = int(parts[3])

# Extract accuracy: after 'acc' -> index 5, but it has '.pt' at the end
# Remove the '.pt' by splitting on '.' and taking the first part
acc_str = parts[5].split('.')[0]   # '0.934'
acc_value = float(acc_str)

print(parts)
print(f"Model architecture: {model_arch}")
print(f"Epoch number: {epoch_num}")
print(f"Accuracy: {acc_value}")
# Out:
# ['model', 'resnet50', 'epoch', '10', 'acc', '0.934.pt']
# Model architecture: resnet50
# Epoch number: 10
# Accuracy: 0.0
