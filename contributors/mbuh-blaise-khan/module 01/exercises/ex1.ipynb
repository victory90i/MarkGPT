# %%
# Dataset name (string)
dataset_name = "customer_churn_2024"
# Number of training samples (integer) – size of the training set
training_samples = 12500

# Model accuracy (float) – performance metric on validation set
model_accuracy = 0.9425

# Flag indicating whether training is complete (boolean)
training_complete = True

# Print values and types
print(f"dataset_name: {dataset_name} -> type: {type(dataset_name)}")
print(f"training_samples: {training_samples} -> type: {type(training_samples)}")
print(f"model_accuracy: {model_accuracy} -> type: {type(model_accuracy)}")
print(f"training_complete: {training_complete} -> type: {type(training_complete)}")
# Out:
# dataset_name: customer_churn_2024 -> type: <class 'str'>
# training_samples: 12500 -> type: <class 'int'>
# model_accuracy: 0.9425 -> type: <class 'float'>
# training_complete: True -> type: <class 'bool'>
