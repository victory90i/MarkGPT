# %%
# Variables for experiment metadata
model_name = "ResNet50"
dataset = "CIFAR-10"
train_acc = 94.30
val_acc = 91.20

# 1. Print formatted summary using f-string with 2 decimal places
summary = f"Model: {model_name} | Dataset: {dataset} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%"
print("Original:", summary)

# 2. .upper() on model name
model_upper = model_name.upper()

# 3. .replace() 'CIFAR-10' with 'ImageNet' in the summary string
modified_summary = summary.replace("CIFAR-10", "ImageNet")
print("Modified:", modified_summary)

# Optional: show the upper-cased model name separately
print(f"Model name in upper case: {model_upper}")
# Out:
# Original: Model: ResNet50 | Dataset: CIFAR-10 | Train Acc: 94.30% | Val Acc: 91.20%
# Modified: Model: ResNet50 | Dataset: ImageNet | Train Acc: 94.30% | Val Acc: 91.20%
# Model name in upper case: RESNET50
