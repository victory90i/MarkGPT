# %%
filename = "model_resnet50_epoch_10_acc_0.934.pt"

filename_no_ext = filename.replace(".pt", "")

parts = filename_no_ext.split("_")

model_architecture = parts[1]         
epoch_number = int(parts[3])           
accuracy = float(parts[5])             

print("Model Architecture:", model_architecture)
print("Epoch:", epoch_number)
print("Accuracy:", accuracy)
# Out:
# Model Architecture: resnet50
# Epoch: 10
# Accuracy: 0.934
