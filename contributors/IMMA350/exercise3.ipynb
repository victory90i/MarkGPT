# %%
val_accuracy = 0.87

if val_accuracy >= 0.95:
    print("Excellent — deploy candidate")
elif val_accuracy >= 0.85:
    print("Good — continue training")
elif val_accuracy >= 0.70:
    print("Needs improvement — review architecture")
else:
    print("Poor — check data pipeline")
# Out:
# Good — continue training
