# %%
dataset_name = "name"

num_samples = 10000

model_accuracy = 0.9


training_complete = True



print(dataset_name, type(dataset_name))
print(num_samples, type(num_samples))
print(model_accuracy, type(model_accuracy))
print(training_complete, type(training_complete))
# Out:
# name <class 'str'>
# 10000 <class 'int'>
# 0.9 <class 'float'>
# True <class 'bool'>
