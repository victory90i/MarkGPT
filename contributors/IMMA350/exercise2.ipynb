# %%
model_name = "ResNet50"
dataset = "CIFAR-10"
train_acc = 94.3
val_acc = 91.2
summary = f"Model: {model_name} | Dataset: {dataset} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%"
print(summary)
model_name_upper = model_name.upper()
updated_summary = summary.replace("CIFAR-10", "ImageNet")

print(model_name_upper)
print(updated_summary)
# Out:
# Model: ResNet50 | Dataset: CIFAR-10 | Train Acc: 94.30% | Val Acc: 91.20%
# RESNET50
# Model: ResNet50 | Dataset: ImageNet | Train Acc: 94.30% | Val Acc: 91.20%
