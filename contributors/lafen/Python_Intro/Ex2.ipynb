# %%
Model = "ResNet50"
Dataset = "CIFAR-10"
Train_Acc = 94.3056
Val_Acc = 91.2065

Summary_text = (f"Model: {Model} | Dataset: {Dataset} | Train_Acc: {Train_Acc}% | Val_Acc: {Val_Acc}% ")
print(Summary_text)
New_summary_text = (f"Model: {Model.upper()} | Dataset: {Dataset.replace(Dataset, "ImageNet")} | Train_Acc: {Train_Acc:.2f}% | Val_Acc: {Val_Acc:.2f}% ") 
print(New_summary_text)
# Out:
# Model: ResNet50 | Dataset: CIFAR-10 | Train_Acc: 94.3056% | Val_Acc: 91.2065%
# Model: RESNET50 | Dataset: ImageNet | Train_Acc: 94.31% | Val_Acc: 91.21%
