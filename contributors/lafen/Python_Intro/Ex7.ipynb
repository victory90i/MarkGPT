# %%
def validate_sample(age, income, credit_score):
    if(age < 0 or income < 0 or credit_score < 0):
        print("Invalid: Negative values are not allowed")
    elif(age < 18 or age > 100):
        print("Invalid: Age out of range")
    elif(income > 1_000_000):
        print("Flag: Unusually high income - review")
    else: 
        print("Valid sample")

# my_age = int(input("Enter your age:"))
# my_income = int(input("Enter your income:"))
# my_credit_score = int(input("Enter your credit score:"))
# validate_sample(my_age, my_income, my_credit_score)                    

validate_sample(25, 50000, 700)
validate_sample(-5, 50000, 700)
validate_sample(25, -50000, 700)
# Out:
# Valid sample
# Invalid: Negative values are not allowed
# Invalid: Negative values are not allowed
