# %%
Name = "model_resnet50_epoch_10_acc_0.934.pt"
print(f"Model name: {Name.split("_")[1]}")
print(f"Epoch number: {int(Name.split("_")[3])}")
acc = Name.replace(Name.split("_")[5], "0.934")
print(f"Accuracy number: {float(acc.split("_")[5])}")
# Out:
# Model name: resnet50
# Epoch number: 10
# Accuracy number: 0.934
