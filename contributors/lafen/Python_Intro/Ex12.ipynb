# %%
Sample = [28, 'engineer', 85000, True, 720]
Dataset = ['age', 'occupation', 'income', 'employed', 'credit_score']
for x, y in zip(Dataset, Sample):
    arrangement = f"{x} : {y}"
    print(arrangement)

loan_approved = False
Sample.append(loan_approved)    
Dataset.append("loan_approved")
print("After appending loan_approved:", Sample)


Dataset.remove('employed')
Sample.remove(True)

for x, y in zip(Dataset, Sample):
    arrangement = f"{x} : {y}"
    print(arrangement)
# Out:
# age : 28
# occupation : engineer
# income : 85000
# employed : True
# credit_score : 720
# After appending loan_approved: [28, 'engineer', 85000, True, 720, False]
# age : 28
# occupation : engineer
# income : 85000
# credit_score : 720
# loan_approved : False
