# %%
dataset = "Python is good"
training_sample = 235
model_accuracy = 67.8
flag = True

print(type(dataset))
print(type(training_sample))
print(type(model_accuracy))
print(type(flag))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
