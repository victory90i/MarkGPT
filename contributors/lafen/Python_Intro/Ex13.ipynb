# %%
model_config = {
    "architecture" : "network",
    "learning_rate" : 0.345,
    "batch_size" : 4,
    "epochs" : 10,
    "optimizer" : "John",
    "dropout_rate" : "0.5"
}

for key, value in model_config.items():
    print(f"{key} : {value}")

model_config["learning_rate"] = 0.08
model_config["early_stopping"] = True
print(model_config)
Regular = model_config.get("regularisation", "none")
print("Regularisation:", Regular)
# Out:
# architecture : network
# learning_rate : 0.345
# batch_size : 4
# epochs : 10
# optimizer : John
# dropout_rate : 0.5
# {'architecture': 'network', 'learning_rate': 0.08, 'batch_size': 4, 'epochs': 10, 'optimizer': 'John', 'dropout_rate': '0.5', 'early_stopping': True}
# Regularisation: none
