# %%
# Using only matplotlib (no seaborn), create a figure with: a title styled in bold navy blue, x and y axis
# labels, a grid with alpha=0.3, and a legend. Plot two lines on the same axes: y = x^2 and y = x^3 for x
# from -3 to 3. Use different colours and linestyles. Add a horizontal dashed line at y=0 and a vertical
# dashed line at x=0.
# This exercise is about matplotlib's low-level API. Notice how much more code it takes compared to
# seaborn.

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-3, 3, 500)  # 300 points for smooth curves
fig, ax=plt.subplots(figsize=(8,5))
# plot() draws a line . color , lw (linewidth) ls=linestyle, label
ax.plot(x, x**2, color='navy', lw=2, ls='-', label='y=x\u00b2')
ax.plot(x, x**3, color='crimson', lw=2, ls='--', label='y=x\u00b3')
# axhline/axvline draw infinite horizontal/vertical lines
ax.axhline(0, color='blue', lw=5, ls='-', alpha=0.9)
ax.axvline(0, color='green', lw=3, ls='-', alpha=0.9)
# stylinmg the titles, labels, grid, legend
ax.set_title('Polynomial functions', fontweight='bold', color='navy')
ax.set_xlabel('x axes', fontsize=12)
ax.set_ylabel('y axes', fontsize=12)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)
plt.tight_layout()
plt.show()
