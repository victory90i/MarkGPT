# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing   import StandardScaler


np.random.seed(42)

temperature = 35 + 10 * np.random.rand(100)

voltage = 215 + 10 * np.random.rand(100)

X = np.column_stack((temperature, voltage))


X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)

scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Before scaling:")
print("mean:", X_train.mean(axis=0))
print("std:", X_train.std(axis=0))

print("\nAfter scaling")
print("mean:", X_train_scaled.mean(axis=0))
print("std:", X_train_scaled.std(axis=0))
# Out:
# Before scaling:
# mean: [ 39.68098562 220.04510339]
# std: [2.91233575 2.87661031]
#
# After scaling
# mean: [ 3.92463839e-15 -2.09859907e-14]
# std: [1. 1.]
