# %%
import numpy as np

array_int = np.array([1, 2, 3], dtype=int)
array_float = np.array([1, 2, 3], dtype=float)
array_bool = np.array([1, 0, 3], dtype=bool)

print(array_int, array_int.dtype)
print(array_float, array_float.dtype)
print(array_bool, array_bool.dtype)
# Out:
# [1 2 3] int64
# [1. 2. 3.] float64
# [ True False  True] bool
