# %%
import numpy as np


A = np.array([[1, 2],
              [4, 5]])   

B = np.array([[7, 8],
              [9, 10]])

mult_a = A@B
mult_b = B@A
element_wise = A*B

print(f"{mult_a} is not equal to {mult_b} which is not equal to A*B ={element_}")
