# %%
print("hello, world")

# %% [markdown]
# ## Introduction to Ai
#
# paragraph ai here

# %%
whole_number = 42
decimal_number = 3.14159
complex_number = 2 + 3j

greeting = "Hello World"
single_char = 'A'

is_sunny = True
is_raining = False

print(type(whole_number))
print(type(greeting))
print(type(complex_number))

# %%
name = "Shumanjah Marvellous"
age = 0
city = "bamenda"
hobby = "Gaming"

print(f"My name is {name} , i {age} years old and i love {hobby}")

# %%
length = 10
width = 5
area = length * width
print(area)

# %%
celsius = 25
fahrenheit = (celsius*9/5) + 32
print(f"celsuis is {celsius} and fahrenheit is {fahrenheit}")
# Out:
# celsuis is 25 and fahrenheit is 77.0

# %%
# Concatenation (joining strings)
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name
print(full_name)  # John Doe

# Repetition
laugh = "Ha" * 3
print(laugh)  # HaHaHa

# Length
message = "Hello, Python!"
print(len(message))  # 14

# Accessing individual characters (like opening specific drawers)
first_letter = message[0]    # H
last_letter = message[-1]
# Out:
# John Doe
# HaHaHa
# 14

# %%
name = "Alice"
age = 30
score = 95.5

# Method 1: f-strings (recommended - like fill-in-the-blank)
print(f"Hello, {name}! You are {age} years old.")
print(f"Your score is {score:.1f}%")

# Method 2: .format() method
print("Hello, {}! You are {} years old.".format(name, age))

# Method 3: % formatting (older style)
print("Hello, %s! You are %d years old." % (name, age))
# Out:
# Hello, Alice! You are 30 years old.
# Your score is 95.5%
# Hello, Alice! You are 30 years old.
# Hello, Alice! You are 30 years old.

# %%
full_name = "johN dOe"
full_name.title()
print(full_name.title())
# Out:
# John Doe

# %%
sentence = "python is an amazing programing language"
print( len(sentence))
# Out:
# 40

# %%
score = 85 

if score >= 80 and score <= 89:
    print("B")
elif score >= 70 and score <= 79:
    print("C")

elif score < 60:
    print("F")
elif score > 89:
    print("A")
else:
    print("not a valid score")
# Out:
# B

# %%
correct_username = 'admin'
correct_password = "password123"

username= "admin"
password = "password123"

if correct_username == username:
    print("Username is correct")
    if correct_password == password:
        print("Password is correct")
    else:
        print("password is wrong")
else:
    print("Username is wrong")
# Out:
# Username is correct
# password is wrong

# %%
sum = 0
for number in range(1, 101):
    sum = sum + number
    number+=1
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 5050

# %%
star = "*"
for number in range(1, 5):
    number+=1
    print(star * number)

# %%
sum = 0
number = 0
while number < 101:
    sum = sum + number
    number+=1
    print(sum)
