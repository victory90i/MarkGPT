# %%
val_accuracy = 0.50
if val_accuracy >= 0.95:
    print("excellent, deploy the model")
elif val_accuracy >= 0.85 and val_accuracy < 0.95:
    print("Good, continue training")
elif val_accuracy >= 0.70 and val_accuracy < 0.85:
    print("needs improvement, review architecture")
else:
    print("poor, check data pipeline")
# Out:
# poor, check data pipeline
