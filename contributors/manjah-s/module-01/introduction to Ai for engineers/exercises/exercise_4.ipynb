# %%
features = ['age', 'income', 'education', 'credit_score', 'loan_amount']

for feature in features:
    print(f"{features.index(feature)}.{feature}")
# Out:
# 0.age
# 1.income
# 2.education
# 3.credit_score
# 4.loan_amount
