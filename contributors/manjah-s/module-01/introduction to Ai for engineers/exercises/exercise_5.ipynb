# %%
file_name = "model_resnet50_epoch_10_acc_0.934.pt"
name = file_name.replace(".pt", "")
parts = name.split("_")
model_arch = parts[1]
epoch = int(parts[3])
accuracy = float(parts[5])

print("model:", model_arch)
print("Epoch", epoch)
print("Accuracy:", accuracy)
# Out:
# model: resnet50
# Epoch 10
# Accuracy: 0.934
