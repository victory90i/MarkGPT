# %%
sample = [28, 'engineer', 85000, True, 720]
Dataset = ['age', 'occupation', 'income', 'employed', 'credit_score']

# %%
for name, value in zip(Dataset, sample):
    print(f"{name}: {value}")
# Out:
# age: 28
# occupation: engineer
# income: 85000
# employed: True
# credit_score: 720

# %%
sample.append(False)
Dataset.append('loan_approved')

# %%
index = name.index('employed')
Dataset.pop(index)
sample.pop(index)

# %%
for name, value in zip(Dataset, sample):
    print(f"{name}: {value}")
# Out:
# age: 28
# occupation: engineer
# income: 85000
# employed: True
# credit_score: 720
# loan_approved: False
