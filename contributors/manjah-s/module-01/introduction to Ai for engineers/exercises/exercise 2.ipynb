# %%
model_name = "ResNet50"
Dataset_used = "cifar-10"
Train_Acc = 94.39
validation_accuracy = 91.20
print(f"model: {model_name.upper()} | dataset: {Dataset_used.upper()}, train acc: {Train_Acc:.2f} | val Acc: {validation_accuracy:.2f}")
# Out:
# model: RESNET50 | dataset: CIFAR-10, train acc: 94.39 | val Acc: 91.20
