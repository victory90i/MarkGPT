# %% [markdown]
# model_config = {
#      "architecture": "neural_network",
#      "learning_rate" : 0.001,
#      "batch_size": 32,
#      "epochs": 50,
#      "optimizer": "adam"
#      "dropout_rate": 0.5
# }

# %%
model_config = { "architecture": "neural_network", "learning_rate" : 0.001, "batch_size": 32, "epochs": 50, "optimizer": "adam", "dropout_rate": 0.5 }
for key, value in model_config.items():
    print(f"{key} : {value}")

model_config["learning_rate"] = 0.0001
model_config["early_stopping"] = True

reg = model_config.get("regularisation", "none")
print("regularisation: ", reg)
# Out:
# architecture : neural_network
# learning_rate : 0.001
# batch_size : 32
# epochs : 50
# optimizer : adam
# dropout_rate : 0.5
# regularisation:  none
