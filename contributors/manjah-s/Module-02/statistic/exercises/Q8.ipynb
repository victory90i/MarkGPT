# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "height_cm": np.random.normal(170,10,100),
    "weight_kg": np.random.normal(70,15,100),
    "age": np.random.randint(18,65,100),
    "category": np.random.choice(['A','B','C'],100)
})

print(df.describe())
print("\n---\n")
print(df.describe(include='all'))
# Out:
#         height_cm   weight_kg         age
# count  100.000000  100.000000  100.000000
# mean   169.110646   70.858904   39.770000
# std      9.612967   15.902221   14.034485
# min    145.247074   28.703870   18.000000
# 25%    163.714292   61.623281   28.000000
# 50%    169.053941   70.136598   39.000000
# 75%    173.219870   81.931710   52.000000
# max    198.928225  107.625119   64.000000
#
# ---
#
#          height_cm   weight_kg         age category
# count   100.000000  100.000000  100.000000      100
# unique         NaN         NaN         NaN        3
# top            NaN         NaN         NaN        C
# freq           NaN         NaN         NaN       44
# mean    169.110646   70.858904   39.770000      NaN
# std       9.612967   15.902221   14.034485      NaN
# min     145.247074   28.703870   18.000000      NaN
# 25%     163.714292   61.623281   28.000000      NaN
# 50%     169.053941   70.136598   39.000000      NaN
# 75%     173.219870   81.931710   52.000000      NaN
# max     198.928225  107.625119   64.000000      NaN
