# %% [markdown]
# Choosing the Right Tool
# Task	     Tool	           Why
# Load CSV	   Pandas	    table data
# Percentile	  NumPy	           math
# Heatmap	      Seaborn	   visualization
# Random Poisson	NumPy	   distributions
# T-test	        SciPy	           statistics
# Precise plot	Matplotlib
