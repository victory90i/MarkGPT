# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

from scipy.stats import kurtosis

normal = np.random.normal(size=1000)
t_dist = np.random.standard_t(3, size=1000)
uniform = np.random.uniform(size=1000)

print("Normal:", kurtosis(normal))
print("T-dist:", kurtosis(t_dist))
print("Uniform:", kurtosis(uniform))
# Out:
# Normal: -0.061441649799428344
# T-dist: 37.6044397435909
# Uniform: -1.220806678174224
