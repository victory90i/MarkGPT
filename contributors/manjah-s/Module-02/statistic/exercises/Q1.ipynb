# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib
import seaborn as sns

versions = {
    "numpy": np.__version__,
    "pandas": pd.__version__,
    "scipy": scipy.__version__,
    "matplotlib": matplotlib.__version__,
    "seaborn": sns.__version__
}

print(versions)
# Out:
# {'numpy': '2.4.4', 'pandas': '3.0.2', 'scipy': '1.17.1', 'matplotlib': '3.10.8', 'seaborn': '0.13.2'}
